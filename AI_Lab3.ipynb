# %%
import pandas as pd
df = pd.read_csv('/content/PriceDataSet.csv')

# %%
df
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        4     40
# 4        5     45
# 5        6     75
# 6        7     90
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.head(10)

# %%
df.tail()
# Out:
#     weight  price
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.tail(10)
# Out:
#     weight  price
# 5        6     75
# 6        7     90
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.corr()
# Out:
#           weight     price
# weight  1.000000  0.989168
# price   0.989168  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   weight  15 non-null     int64
#  1   price   15 non-null     int64
# dtypes: int64(2)
# memory usage: 368.0 bytes

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/PriceDataSet.csv')

df.plot()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/PriceDataSet.csv')

df.plot(kind = 'scatter', x = 'weight', y = 'price')
plt.xlabel("Weight of potato")
plt.ylabel("Price of potato")
plt.title("Predictation")
plt.show()

# %%
df["weight"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd
df = pd.read_csv('/content/a.csv')
df
new_df = df.dropna()

print(new_df.to_string())
# Out:
#     weight  price
# 0      1.0   10.0
# 1      2.0   20.0
# 2      3.0   25.0
# 3      4.0   40.0
# 4      5.0   45.0
# 5      6.0   75.0
# 6      7.0   90.0
# 7      8.0  100.0
# 8      9.0  115.0
# 9     10.0  120.0
# 11    12.0  132.0
# 12    13.0  140.0
# 13    14.0  160.0
# 14    15.0  165.0

# %%
new_df1 =df.fillna("AI lab")
print(new_df1)
# Out:
#     weight   price
# 0      1.0    10.0
# 1      2.0    20.0
# 2      3.0    25.0
# 3      4.0    40.0
# 4      5.0    45.0
# 5      6.0    75.0
# 6      7.0    90.0
# 7      8.0   100.0
# 8      9.0   115.0
# 9     10.0   120.0
# 10  AI lab  AI lab
# 11    12.0   132.0
# 12    13.0   140.0
# 13    14.0   160.0
# 14    15.0   165.0

# %%
x = df["weight"].mean()
print(f"Mean is {x}")
new_df=df.fillna(x)
print(new_df)
# Out:
# Mean is 7.785714285714286
#        weight       price
# 0    1.000000   10.000000
# 1    2.000000   20.000000
# 2    3.000000   25.000000
# 3    4.000000   40.000000
# 4    5.000000   45.000000
# 5    6.000000   75.000000
# 6    7.000000   90.000000
# 7    8.000000  100.000000
# 8    9.000000  115.000000
# 9   10.000000  120.000000
# 10   7.785714    7.785714
# 11  12.000000  132.000000
# 12  13.000000  140.000000
# 13  14.000000  160.000000
# 14  15.000000  165.000000

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
df = pd.read_csv('/content/b.csv')
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# dtype: bool

# %%
new_df=df.drop_duplicates()
print(new_df)
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        4     40
# 4        5     45
# 5        6     75
# 6        7     90
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.describe()
# Out:
#           weight       price
# count  20.000000   20.000000
# mean    8.450000   97.350000
# std     4.248529   48.913753
# min     1.000000   10.000000
# 25%     5.750000   67.500000
# 50%     8.500000  107.500000
# 75%    12.250000  134.000000
# max    15.000000  165.000000
